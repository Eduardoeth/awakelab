# %%
n=1
while n<2:
    x = str(input("1.-¿Julieta es nombre de mujer?. Con t si es True o f si e False:  "))
    x = x.lower()

    n=n+1
    T=str("t")
    F=str("f")
    if x==T:
        print("Correcto")
        break
    if x==F:
        print("Incorrecto")
        break
    else:
        print("t si es True o f si e False")
        n=n-1

        
print("____________________________________________________________________")       
n=1
while n<2:
    x = str(input("2.-¿Perro es un animal?. Con t si es True o f si e False:  "))
    x = x.lower()
    n=n+1
    T=str("t")
    F=str("f")
    if x==T:
        print("Correcto")
        break
    if x==F:
        print("Incorrecto")
        break
    else:
        print("t si es True o f si e False")
        n=n-1
        
print("____________________________________________________________________")       
n=1
while n<2:
    x = str(input("3.-¿Gato es un pez?. Con t si es True o f si e False:  "))
    x = x.lower()
    n=n+1
    T=str("t")
    F=str("f")
    if x==T:
        print("Incorrecto")
        break
    if x==F:
        print("Correcto")
        break
    else:
        print("t si es True o f si e False")
        n=n-1
        
print("____________________________________________________________________")        
n=1
while n<2:
    x = str(input("4.-¿El sol es una estrella?. Con t si es True o f si e False:  "))
    x = x.lower()
    n=n+1
    T=str("t")
    F=str("f")
    if x==T:
        print("Correcto")
        break
    if x==F:
        print("Incorrecto")
        break
    else:
        print("t si es True o f si e False")
        n=n-1

        
print("____________________________________________________________________")        
n=1
while n<2:
    x = str(input("5.-¿2 + 2 = 5?. Con t si es True o f si e False:  "))
    x = x.lower()
    n=n+1
    T=str("t")
    F=str("f")
    if x==T:
        print("Incorrecto")
        break
    if x==F:
        print("Correcto")
        break
    else:
        print("t si es True o f si e False")
        n=n-1
        
        
print("____________________________________________________________________")        
a=int(15/5)
b=int(3)
c=(a==b)
c=str(c)
x = str(input("6.-¿15/5 es igual a 3?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)


        
print("____________________________________________________________________")        
a=int(5)
b=int(2)
c=(a==b)
c=str(c)
x = str(input("6.-¿5 es igual a 2?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)


        
print("____________________________________________________________________")        
a=int(2)
b=int(4)
c=(a<b)
c=str(c)
x = str(input("7.-¿4 es mayor que 2?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)


        
print("____________________________________________________________________")        
a=int(2020)
b=int(2000)
c=(a<b)
c=str(c)
x = str(input("8.-¿2000 es mayor que 2020?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)

        
print("____________________________________________________________________")        
a=int(80/2)
b=int(20*2)
c=(a==b)
c=str(c)
x = str(input("9.-¿80/2 es igual que 20*2?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)

print("____________________________________________________________________")        
a=int(-100)
b=int(-200/2)
c=(a==b)
c=str(c)
x = str(input("10.-¿-100 es igual que -200/10?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
print("____________________________________________________________________")        
a=int(100/2)
b=int(20*2)
c=(a>=b)
c=str(c)
x = str(input("11.-¿100/2 es mayor o igual que 20*2?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
print("____________________________________________________________________")        
a=int(8)
b=int(20*2)
c=(a<=b)
c=str(c)
x = str(input("12.-¿8 es menor o igual que 20*2?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
        
print("____________________________________________________________________")        
a=str("Azul")
    a = a.lower()
b=str("celeste")
    b = b.lower()
c=(a==b)
c=str(c)
x = str(input("13.-¿Azul es igual que celeste?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
        
print("____________________________________________________________________")        

a=str("Azul")
a = a.lower()
b=str("Azul")
b = b.lower()
c=(a==b)
c=str(c)
x = str(input("14.-¿Azul es igual que blue?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
        
print("____________________________________________________________________")        
a=str("Julieta")
a = a.lower()
b=str("Juliet")
b = b.lower()
c=(a==b)
c=str(c)
x = str(input("15.-¿Julieta es igual que Juliet?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
 
        
print("____________________________________________________________________")        
a=str("azul")
a = a.lower()
b=str("asul")
b = b.lower()
c=(a==b)

a1=str("20")
a1 = a1.lower()
b1=str("21")
b1 = b1.lower()
c1=(a1>b1)

c=(c and c1)
c=str(c)
x = str(input("16.-¿azul es igual que asul y 20 es mayor que 21 ?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
 
print("____________________________________________________________________")        
a=str("amarillo")
a = a.lower()
b=str("rojo")
b = b.lower()
c=(a==b)

a1=str("20/2")
a1 = a1.lower()
b1=str("10")
b1 = b1.lower()
c1=(a1==b1)

c=(c or c1)
c=str(c)
x = str(input("17.-¿amarillo es igual que rojo o 20/2 es igual que 10 ?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
 
print("____________________________________________________________________")        
a=str("1231")
a = a.lower()
b=str("1234")
b = b.lower()
c=(a==b)

a1=str("6785")
a1 = a1.lower()
b1=str("6785")
b1 = b1.lower()
c1=(a1==b1)

c=(c or c1)
c=str(c)
x = str(input("18.-¿1231 es igual que 1234 o 6785 es igual que 6785 ?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
 
        
print("____________________________________________________________________")        
a=str("202")
a = a.lower()
b=str("201")
b = b.lower()
c=(a>=b)

a1=str("10.999")
a1 = a1.lower()
b1=str("10.99")
b1 = b1.lower()
c1=(a1==b1)

c=(c or c1)
c=str(c)
x = str(input("19.-¿202 es mayor o igual que 201 o 10.999 es igual que 10.99 ?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
print("____________________________________________________________________")        
a=str("202")
a = a.lower()
b=str("201")
b = b.lower()
c=(a>=b)

a1=str("10.999")
a1 = a1.lower()
b1=str("10.99")
b1 = b1.lower()
c1=(a1==b1)

c=(c or c1)
c=str(c)
x = str(input("20.-¿202 es mayor o igual que 201 o 10.999 es igual que 10.99 ?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
 
        
        
print("____________________________________________________________________")        
a=str("0.2")
a = a.lower()
b=str("0.201")
b = b.lower()
c=(a>b)

a1=str("0.2")
a1 = a1.lower()
b1=str("0.201")
b1 = b1.lower()
c1=(a1==b1)

c=(c or c1)
c=str(c)
x = str(input("21.-¿0.2 es mayor 0.201 o 0.2 es igual que 0.201 ?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)        
        
        
        
        
print("____________________________________________________________________")        

lista = [1, 50, 30]
c=(50 in lista)
c=str(c)
x = str(input("22.-¿El número 50 existe en la lista [1, 50, 30]?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
        
        
print("____________________________________________________________________")        

lista = ["perro", "gato", "conejo"]
c=("caballo" in lista)
c=str(c)
x = str(input("13.-¿El número caballo existe en la lista ["perro", "gato", "conejo"]?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
        
print("____________________________________________________________________")        

lista = [10, 20, 30]
c=(40 in lista)
c=str(c)
x = str(input("13.-¿El número40 existe en la lista [10, 20, 30]?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
        
        
print("____________________________________________________________________")        

lista = [1, 50, 30]
c=(20 in lista)
c=str(c)
x = str(input("13.-¿El número 20 no existe en la lista [1, 50, 30]?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
# Out:
# 1.-¿Julieta es nombre de mujer?. Con t si es True o f si e False:  f
# Incorrecto
# ____________________________________________________________________
# 2.-¿Perro es un animal?. Con t si es True o f si e False:  v
# t si es True o f si e False
# 2.-¿Perro es un animal?. Con t si es True o f si e False:  f
# Incorrecto
# ____________________________________________________________________
# 3.-¿Gato es un pez?. Con t si es True o f si e False:  t
# Incorrecto
# ____________________________________________________________________
# 4.-¿El sol es una estrella?. Con t si es True o f si e False:  f
# Incorrecto
# ____________________________________________________________________

# %%
a=int(15/5)
b=int(3)
c=(a==b)
c=str(c)
x = str(input("12.-¿15/5 es igual a 3?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
# Out:
# 12.-¿15/5 es igual a 3?. Con t si es True o f si e False:  t
# Tu respuesta es  verdadera

# %%
a=int(2)
b=int(4)
c=(a<b)
c=str(c)
x = str(input("12.-¿4 es mayor que 2?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
# Out:
# 12.-¿4 es mayor que 2?. Con t si es True o f si e False:  t
# Tu respuesta es  verdadera

# %%
a=str("Azul")
a = a.lower()
b=str("celeste")
b = b.lower()
c=(a==b)
c=str(c)
x = str(input("13.-¿Azul es igual que celeste?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
# Out:
# 13.-¿Azul es igual que celeste?. Con t si es True o f si e False:  f
# Tu respuesta es  verdadera

# %%
a=str("azul")
a = a.lower()
b=str("asul")
b = b.lower()
c=(a==b)

a1=str("20")
a1 = a1.lower()
b1=str("21")
b1 = b1.lower()
c1=(a1>b1)

c=(c and c1)
c=str(c)
print(c)
# Out:
# False

# %%
lista = [1, 50, 30]
c=(50 in lista)
c=str(c)
x = str(input("13.-¿El número 50 existe en la lista [1, 50, 30]?. Con t si es True o f si e False:  "))
x = x.lower()
if x=="t":
    x=str("True")
else:
    x=str("False")

z =(c==x)

if z==False:
    z=str("errada")
else:
    z=str("verdadera")
    

print("Tu respuesta es ", z)
# Out:
# 13.-¿El número 50 existe en la lista [1, 50, 30]?. Con t si es True o f si e False:  t
# Tu respuesta es  verdadera

# %%
lista = [1, 50, 30]
c=(50 in lista)
print(c)
# Out:
# True
